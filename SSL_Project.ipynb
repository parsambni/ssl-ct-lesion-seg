# %%
import os
import shutil
from google.colab import drive

# ================== تنظیمات اصلاح شده ==================
TOKEN = "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"
USER = "parsambni"
REPO = "ssl-ct-lesion-seg"

# 👇👇👇 اسم فایل را دقیقاً مطابق عکس درایوت درست کردم
FILE_NAME = "Copy of Task08_HepaticVessel.tar"
# =======================================================

# ۱. دانلود کدها (چون قبلاً دانلود شده، فقط وارد پوشه می‌شود)
if os.path.exists(REPO):
    print(f"✅ پوشه کدها ({REPO}) موجود است.")
else:
    print(f"🚀 در حال دانلود کدها...")
    # !git clone https://{TOKEN}@github.com/{USER}/{REPO}.git

# %cd {REPO}

# ۲. اتصال به درایو
# (چون گفتی Drive already mounted، این خط را رد می‌کند یا فقط چک می‌کند)
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# ۳. کپی و استخراج
drive_path = f'/content/drive/MyDrive/{FILE_NAME}'
local_path = f'/content/{FILE_NAME}' # اسم فایل در کولب را ساده می‌کنیم
dataset_dir = '/content/dataset'

if os.path.exists(drive_path):
    print(f"⏳ فایل پیدا شد! در حال کپی کردن {FILE_NAME} (۳ تا ۵ دقیقه صبر کن)...")
    shutil.copy(drive_path, local_path)

    print("⏳ کپی تمام شد. در حال استخراج (Unzip)...")
    if not os.path.exists(dataset_dir):
        os.makedirs(dataset_dir)
    # !tar -xf "{local_path}" -C {dataset_dir}
    print("🎉 تبریک! دیتاست و کدها آماده‌اند.")
else:
    print(f"❌ هنوز هم فایل را پیدا نمی‌کنم! مطمئن شو فایل '{FILE_NAME}' دقیقاً در صفحه اصلی درایو (My Drive) باشد.")
# Out:
# 🚀 در حال دانلود کدها...
# Cloning into 'ssl-ct-lesion-seg'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 46 (delta 0), reused 46 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 54.32 KiB | 806.00 KiB/s, done.
# /content/ssl-ct-lesion-seg/ssl-ct-lesion-seg/ssl-ct-lesion-seg/ssl-ct-lesion-seg/ssl-ct-lesion-seg/ssl-ct-lesion-seg
# ⏳ فایل پیدا شد! در حال کپی کردن Copy of Task08_HepaticVessel.tar (۳ تا ۵ دقیقه صبر کن)...
# ⏳ کپی تمام شد. در حال استخراج (Unzip)...
# 🎉 تبریک! دیتاست و کدها آماده‌اند.

# %%
import os

# ۱. رفتن به پوشه اصلی پروژه
# (چون توی خروجی دیدم چند بار تو هم تو هم شده بود، این خط ما را می‌برد جای درست)
# %cd /content/ssl-ct-lesion-seg

print("📍 الان اینجا هستیم:")
# !pwd
print("📂 لیست فایل‌های موجود:")
# !ls

# ۲. نصب کتابخانه‌های لازم
if os.path.exists('requirements.txt'):
    print("⏳ در حال نصب کتابخانه‌های مورد نیاز (چند دقیقه طول می‌کشد)...")
    # !pip install -r requirements.txt
    print("✅ نصب تمام شد.")
else:
    print("⚠️ فایل requirements.txt پیدا نشد! (اگر ارور نداد، شاید لازم نیست).")
# Out:
# /content/ssl-ct-lesion-seg
# 📍 الان اینجا هستیم:
# /content/ssl-ct-lesion-seg
# 📂 لیست فایل‌های موجود:
# configs			    pyproject.toml	scripts
# DATASET_SUPPORT.md	    QUICK_REFERENCE.md	src
# IMPLEMENTATION_COMPLETE.md  README.md		ssl-ct-lesion-seg
# IMPLEMENTATION_SUMMARY.md   requirements.txt	tests
# ⏳ در حال نصب کتابخانه‌های مورد نیاز (چند دقیقه طول می‌کشد)...
# ...
# ✅ نصب تمام شد.

# %%
print("📂 بیاییم ببینیم دیتاست دقیقاً کجا ریخته شده:")
# !ls /content/dataset

print("\n📄 بیاییم ببینیم فایل اصلی اجرای برنامه اسمش چیه (داخل src):")
# !ls src

print("\n⚙️ بیاییم ببینیم فایل تنظیمات چی داریم:")
# !ls configs
# Out:
# 📂 بیاییم ببینیم دیتاست دقیقاً کجا ریخته شده:
# Task08_HepaticVessel
#
# 📄 بیاییم ببینیم فایل اصلی اجرای برنامه اسمش چیه (داخل src):
# data.py     __init__.py  metrics.py  ssl.py	      transforms.py
# dataset.py  losses.py	 models.py   train_engine.py  utils.py
#
# ⚙️ بیاییم ببینیم فایل تنظیمات چی داریم:
# base.yaml			ssl_meanteacher.yaml
# ssl_meanteacher_targetaug.yaml	supervised.yaml

# %%
print("📂 محتویات پوشه scripts:")
# !ls scripts
# Out:
# 📂 محتویات پوشه scripts:
# demo_dataset.py  make_splits.py  sanity_viz.py
# eval.py		 run_compare.py  train.py

# %%
print("📄 محتویات فایل تنظیمات (Supervised):")
# !cat configs/supervised.yaml

print("\n❓ راهنمای اجرای فایل train:")
# !python scripts/train.py --help
# Out:
# 📄 محتویات فایل تنظیمات (Supervised):
# # Supervised baseline U-Net training
# # Extends base.yaml
#
# method: "supervised"
#
# # Supervised-specific
# train_mode: "supervised"
# num_labeled_epochs: 50
#
# ❓ راهنمای اجرای فایل train:
# usage: train.py [-h] [--config CONFIG] [--data_root DATA_ROOT] [--seed SEED]
#                 [--labeled_ratio LABELED_RATIO] [--smoke]
#
# Train segmentation model
#
# options:
#   -h, --help            show this help message and exit
#   --config CONFIG
#   --data_root DATA_ROOT
#   --seed SEED
#   --labeled_ratio LABELED_RATIO
#   --smoke

# %%
# نمایش محتویات فایل تنظیمات برای چک کردن آدرس دیتاست
print("📄 محتویات فایل کانفیگ:")
# !cat configs/supervised.yaml
# Out:
# 📄 محتویات فایل کانفیگ:
# # Supervised baseline U-Net training
# # Extends base.yaml
#
# method: "supervised"
#
# # Supervised-specific
# train_mode: "supervised"
# num_labeled_epochs: 50

# %%
import os

print("📋 وضعیت نهایی قبل از شروع:")

# ۱. چک کردن فایل اجرا
if os.path.exists("scripts/train.py"):
    print("✅ فایل اجرایی (train.py) حاضره.")
else:
    print("❌ فایل train نیست!")

# ۲. چک کردن دیتاست
if os.path.exists("/content/dataset/Task08_HepaticVessel"):
    print("✅ پوشه دیتاست سر جاشه.")
    # شمردن تعداد فایل‌ها برای اطمینان
    num_files = len(os.listdir("/content/dataset/Task08_HepaticVessel"))
    print(f"   (تعداد فایل‌های داخلش: {num_files} تا)")
else:
    print("❌ دیتاست پیدا نشد!")

print("\n🚀 وضعیت: آماده شلیک! (ولی هنوز شلیک نکردیم)")
# Out:
# 📋 وضعیت نهایی قبل از شروع:
# ✅ فایل اجرایی (train.py) حاضره.
# ✅ پوشه دیتاست سر جاشه.
#    (تعداد فایل‌های داخلش: 8 تا)
#
# 🚀 وضعیت: آماده شلیک! (ولی هنوز شلیک نکردیم)

# %%
# ⚠️ هشدار: این کد آموزش مدل را شروع می‌کند!
# فقط وقتی بزن که می‌خواهی سیستم چند ساعت درگیر شود.

# !python scripts/train.py \
  --config configs/supervised.yaml \
  --data_root /content/dataset \
  --labeled_ratio 0.1  # (اختیاری) مثلاً فقط با ۱۰ درصد لیبل‌ها
